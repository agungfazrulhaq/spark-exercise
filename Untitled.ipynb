# %%
import pandas as pd

# %%
# %%time
df20m = pd.read_csv("../data/creditfraud_20M.csv")
df20m.head(10)
# Out:
# CPU times: user 1min 7s, sys: 2.59 s, total: 1min 9s
# Wall time: 1min 9s
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  108921.0 -0.094002  0.852210  0.744658 -0.139024 -0.087394 -1.538037
# 1    7593.0 -0.460250  1.095884  1.954878  0.517133  0.320600  0.080721
# 2  113906.0  0.091539  0.707590 -0.281279 -1.023973  1.087543  0.048271
# 3   86140.0 -0.722943  0.374674  1.889603  1.283555  0.589860 -0.347929
# 4   43446.0 -1.244502  0.574682  1.645834 -0.842826  1.298392  1.249265
# 5  153702.0  1.915812 -1.030334 -1.178539 -0.446221 -1.014845 -1.008423
# 6  136247.0 -1.991231  0.487900 -0.085682 -1.993552 -0.919154 -0.704924
# 7  109465.0 -0.303967  1.250409  1.609933  3.530058  1.303071  0.393169
# 8  128410.0  1.841167 -0.868040 -0.316137  0.519588 -0.850270  0.024948
# 9  127004.0  1.903194 -0.117705 -2.812465  0.321274  1.080264 -1.207227
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# ...

# %%
df20m.shape
# Out:
# (20000000, 31)

# %%
# %%time
df20m.sort_values(by="V1").head(10)
# Out:
# CPU times: user 9.36 s, sys: 7.3 s, total: 16.7 s
# Wall time: 16.9 s
#              Time        V1         V2        V3         V4         V5  \
# 2316333   39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 18207316  39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 1462607   39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 7868662   39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 19274394  39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 10468927  39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 13696527  39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 11190150  39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 11078305  39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
# 1430489   39954.0 -56.40751 -72.715728 -6.605265  16.491217  34.801666
#
#                  V6         V7      V8        V9  ...       V21       V22  \
# ...

# %%
df20m.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.000000e+07  2.000000e+07  2.000000e+07  2.000000e+07  2.000000e+07
# mean   9.483273e+04  2.400284e-04 -7.119234e-04 -6.273801e-04  2.382386e-04
# std    4.749429e+04  1.960812e+00  1.655654e+00  1.516902e+00  1.415966e+00
# min    0.000000e+00 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%    5.421200e+04 -9.199865e-01 -5.986553e-01 -8.910393e-01 -8.481503e-01
# 50%    8.472800e+04  1.848873e-02  6.535402e-02  1.793976e-01 -1.973040e-02
# 75%    1.393430e+05  1.315771e+00  8.036057e-01  1.026701e+00  7.433026e-01
# max    1.727920e+05  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.000000e+07  2.000000e+07  2.000000e+07  2.000000e+07  2.000000e+07
# mean  -8.058133e-05  2.193785e-05  2.578714e-04 -5.662008e-05  3.252926e-04
# ...
